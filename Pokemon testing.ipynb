# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df =  pd.read_csv('pokemon.csv')
#df_xlsx = pd.read_excel('pokemon_data.xlsx')
#.df =pd.read_csv('pokemon.txt', delimiter ='t') 
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
### Read Headers
#print(df.columns)
### Read each column
#print(df['name'])
### Read list of column
#print(df[['name', 'type1', 'hp']][0:5])
### print Each Row
#print(df.head(4))
### print Specific Row
#print(df.iloc[1:4])
### iterating through rows
##for index, row in df.iterrows():
    ##print(index,row)
df.loc[df['type1']=="fire"]
## Read a specific location
#print(df.iloc[5,8])
# Out:
#                                              abilities  against_bug  \
# 3                             ['Blaze', 'Solar Power']         0.50
# 4                             ['Blaze', 'Solar Power']         0.50
# 5                             ['Blaze', 'Solar Power']         0.25
# 36   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...         0.50
# 37   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...         0.50
# 57           ['Intimidate', 'Flash Fire', 'Justified']         0.50
# 58           ['Intimidate', 'Flash Fire', 'Justified']         0.50
# 76            ['Run Away', 'Flash Fire', 'Flame Body']         0.50
# 77            ['Run Away', 'Flash Fire', 'Flame Body']         0.50
# 125                     ['Flame Body', 'Vital Spirit']         0.50
# 135                             ['Flash Fire', 'Guts']         0.50
# 145                         ['Pressure', 'Flame Body']         0.25
# 154                            ['Blaze', 'Flash Fire']         0.50
# ...

# %% [markdown]
#  Sorting/Describing Data

# %%
df.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
 df.sort_values('name', ascending=True)
# Out:
#                                          abilities  against_bug  against_dark  \
# 459                 ['Snow Warning', 'Soundproof']         2.00           1.0
# 62   ['Synchronize', 'Inner Focus', 'Magic Guard']         2.00           2.0
# 358        ['Pressure', 'Super Luck', 'Justified']         2.00           0.5
# 616       ['Hydration', 'Sticky Hold', 'Unburden']         1.00           1.0
# 680                              ['Stance Change']         0.25           2.0
# ..                                             ...          ...           ...
# 570                                   ['Illusion']         2.00           0.5
# 569                                   ['Illusion']         2.00           0.5
# 40                  ['Inner Focus', 'Infiltrator']         0.25           1.0
# 633                                     ['Hustle']         2.00           0.5
# 717              ['Aura Break', 'Power Construct']         1.00           1.0
#
# ...

# %%
df.sort_values(['type1','hp'], ascending = [1,0])
# Out:
#                                           abilities  against_bug  \
# 793                                 ['Beast Boost']          0.5
# 468         ['Speed Boost', 'Tinted Lens', 'Frisk']          0.5
# 636                         ['Flame Body', 'Swarm']          0.5
# 213                      ['Swarm', 'Guts', 'Moxie']          0.5
# 616        ['Hydration', 'Sticky Hold', 'Unburden']          1.0
# ..                                              ...          ...
# 97   ['Hyper Cutter', 'Shell Armor', 'Sheer Force']          1.0
# 115                ['Swift Swim', 'Sniper', 'Damp']          1.0
# 119      ['Illuminate', 'Natural Cure', 'Analytic']          1.0
# 128                       ['Swift Swim', 'Rattled']          1.0
# 348     ['Swift Swim', 'Oblivious', 'Adaptability']          1.0
#
#      against_dark  against_dragon  against_electric  against_fairy  \
# 793           0.5             1.0               1.0            2.0
# ...

# %% [markdown]
# Making Changing to our data

# %%
df.head(5)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df['Total'] = df['hp']+ df['defense'] + df['attack'] + df['speed']
df.head(5)
df = df.drop(columns = ['Total'])
df.head(5)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df['Total'] = df.iloc[:,4:9].sum(axis=1)
df.head(5)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  pokedex_number  sp_attack  sp_defense  \
# ...

# %%
df[['Total','hp', 'defense']]
df.head(5)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  pokedex_number  sp_attack  sp_defense  \
# ...

# %%
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    Total  against_electric  against_fairy  against_fight  against_fire  \
# 0    5.5               0.5            0.5            0.5           2.0
# 1    5.5               0.5            0.5            0.5           2.0
# 2    5.5               0.5            0.5            0.5           2.0
# 3    4.0               1.0            0.5            1.0           0.5
# 4    4.0               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  against_grass  against_ground
# ...

# %% [markdown]
# saving our data

# %%
#df.to_csv('modified.csv')

# %%
#df.to_csv('modified.csv', index=False)

# %%
df.to_csv('modified.xlsx', index =False)

# %% [markdown]
# #df.to_csv('modified.txt', index = False, sep ='\t')

# %% [markdown]
# Filtering Data

# %%
#df.loc[(df['type1'] == 'grass') & (df['type2'] == 'Poison')]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df =  pd.read_csv('pokemon.csv')
df.loc[(df['type1'] == 'grass') & (df['type2'] == 'poison') &  (df['hp']>70)]
# Out:
#                            abilities  against_bug  against_dark  \
# 2        ['Overgrow', 'Chlorophyll']          1.0           1.0
# 44   ['Chlorophyll', 'Effect Spore']          1.0           1.0
# 70       ['Chlorophyll', 'Gluttony']          1.0           1.0
# 590  ['Effect Spore', 'Regenerator']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 2               1.0               0.5            0.5            0.5
# 44              1.0               0.5            0.5            0.5
# 70              1.0               0.5            0.5            0.5
# 590             1.0               0.5            0.5            0.5
#
#      against_fire  against_flying  against_ghost  ...  percentage_male  \
# 2             2.0             2.0            1.0  ...             88.1
# 44            2.0             2.0            1.0  ...             50.0
# 70            2.0             2.0            1.0  ...             50.0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df =  pd.read_csv('pokemon.csv')
new_df = df.loc[(df['type1'] == 'grass') & (df['type2'] == 'poison') &  (df['hp']>70)]
new_df.to_csv('filtered.csv')
new_df = new_df.reset_index()
new_df
# Out:
#    index                        abilities  against_bug  against_dark  \
# 0      2      ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1     44  ['Chlorophyll', 'Effect Spore']          1.0           1.0
# 2     70      ['Chlorophyll', 'Gluttony']          1.0           1.0
# 3    590  ['Effect Spore', 'Regenerator']          1.0           1.0
#
#    against_dragon  against_electric  against_fairy  against_fight  \
# 0             1.0               0.5            0.5            0.5
# 1             1.0               0.5            0.5            0.5
# 2             1.0               0.5            0.5            0.5
# 3             1.0               0.5            0.5            0.5
#
#    against_fire  against_flying  ...  percentage_male  pokedex_number  \
# 0           2.0             2.0  ...             88.1               3
# 1           2.0             2.0  ...             50.0              45
# 2           2.0             2.0  ...             50.0              71
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df =  pd.read_csv('pokemon.csv')
new_df = df.loc[(df['type1'] == 'grass') & (df['type2'] == 'poison') &  (df['hp']>70)]
new_df.to_csv('filtered.csv')
new_df.reset_index(drop=True, inplace = True)
new_df
# Out:
#                          abilities  against_bug  against_dark  against_dragon  \
# 0      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Chlorophyll', 'Effect Spore']          1.0           1.0             1.0
# 2      ['Chlorophyll', 'Gluttony']          1.0           1.0             1.0
# 3  ['Effect Spore', 'Regenerator']          1.0           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               0.5            0.5            0.5           2.0
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 0             2.0            1.0  ...             88.1               3
# 1             2.0            1.0  ...             50.0              45
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df =  pd.read_csv('pokemon.csv')
df.loc[~df['name'].str.contains('mega')]
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

df =  pd.read_csv('pokemon.csv')
#df.loc[df['type1'].str.contains('fire|grass', regex =True)]
df.loc[df['type1'].str.contains('Fire|Grass', flags=re.I, regex =True)]
# Out:
#                                            abilities  against_bug  \
# 0                        ['Overgrow', 'Chlorophyll']          1.0
# 1                        ['Overgrow', 'Chlorophyll']          1.0
# 2                        ['Overgrow', 'Chlorophyll']          1.0
# 3                           ['Blaze', 'Solar Power']          0.5
# 4                           ['Blaze', 'Solar Power']          0.5
# ..                                               ...          ...
# 761        ['Leaf Guard', 'Oblivious', 'Sweet Veil']          2.0
# 762  ['Leaf Guard', 'Queenly Majesty', 'Sweet Veil']          2.0
# 775                                  ['Shell Armor']          0.5
# 786                    ['Grassy Surge', 'Telepathy']          1.0
# 797                                  ['Beast Boost']          1.0
#
#      against_dark  against_dragon  against_electric  against_fairy  \
# 0             1.0             1.0               0.5            0.5
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

df =  pd.read_csv('pokemon.csv')

df.loc[df['name'].str.contains('^pi[a-z]*', flags=re.I, regex =True)]
# Out:
#                                      abilities  against_bug  against_dark  \
# 15   ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50           1.0
# 16   ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50           1.0
# 17   ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50           1.0
# 24                  ['Static', 'Lightningrod']         1.00           1.0
# 126  ['Hyper Cutter', 'Mold Breaker', 'Moxie']         1.00           1.0
# 171                 ['Static', 'Lightningrod']         1.00           1.0
# 203                     ['Sturdy', 'Overcoat']         1.00           1.0
# 220   ['Oblivious', 'Snow Cloak', 'Thick Fat']         1.00           1.0
# 392                     ['Torrent', 'Defiant']         1.00           1.0
# 498                     ['Blaze', 'Thick Fat']         0.25           0.5
# 518     ['Big Pecks', 'Super Luck', 'Rivalry']         0.50           1.0
# 730       ['Keen Eye', 'Skill Link', 'Pickup']         0.50           1.0
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

df =  pd.read_csv('pokemon.csv')
df.loc[df['type1'] =='fire', 'type1'] = 'Fire'
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

df =  pd.read_csv('pokemon.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

df =  pd.read_csv('pokemon.csv')
df['Total'] = df.iloc[:,4:9].sum(axis=1)
df.loc[df['Total'] >5, ['generation', 'is_legendary']]=['Test1', 'Test2']
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1028\1325952426.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Test1' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total'] >5, ['generation', 'is_legendary']]=['Test1', 'Test2']
# C:\Users\HP\AppData\Local\Temp\ipykernel_1028\1325952426.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Test2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total'] >5, ['generation', 'is_legendary']]=['Test1', 'Test2']
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# ...

# %% [markdown]
# AGGREGATE STATISTICS(GROUPBY)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

df =  pd.read_csv('modified.csv')
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

df =  pd.read_csv('modified.csv')
#df.groupby(['type1']).mean().sort_values('defense', ascending = False)
#df.groupby(['type1']).count()
